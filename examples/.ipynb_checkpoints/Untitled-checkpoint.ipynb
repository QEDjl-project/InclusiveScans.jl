# %%
using Random
RNG = MersenneTwister(1234)
using BenchmarkTools

using ConstrainedGaussians
# Out:
# [ Info: Precompiling ConstrainedGaussians [72cb5a96-92ad-43ae-9774-2d852a9e5056] (cache misses: include_dependency fsize change (4))

# %%
 
mu = rand(RNG)
sig = rand(RNG)

dom = (mu+0.5*sig,mu+3.0*sig)
d = ConstrainedGaussian1D(mu,sig,dom)
N = Int(1e6)
# Out:
# 1000000

# %%
samples = generate_CPU(RNG,d,N ; batch_size=1000) # not enough elements????
# Out:
# 1000054-element Vector{Float64}:
#  1.2040431684825084
#  0.7774733124923934
#  0.6126867903864357
#  0.9392745795157009
#  0.8156498033678987
#  0.570897919146562
#  0.7412080541225979
#  0.8425304885834133
#  0.6829143976006387
#  0.5240125307746007
#  0.895176061532615
#  0.576689586977971
#  1.4782570470406649
#  ⋮
#  1.0024458796289286
#  0.5396914793532551
#  1.5210951186477581
#  0.6847803100366838
#  0.5964880507385865
#  0.5826660809250056
#  0.7691912940839236
#  1.0115640218865827
#  1.1274879344391264
#  0.5274267110467713
#  1.0595893544391146
#  1.2196136952319203

# %%
plot_compare(samples,d)

# %%
N = 10000

@benchmark generate_CPU($RNG,$d,$N)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1 evaluation per sample.
#  Range (min … max):  276.917 μs …  13.116 ms  ┊ GC (min … max):  0.00% … 97.08%
#  Time  (median):     331.416 μs               ┊ GC (median):     0.00%
#  Time  (mean ± σ):   378.852 μs ± 317.848 μs  ┊ GC (mean ± σ):  12.24% ± 14.09%
#
#   ▅▇█▆▃                                                         ▂
#   ██████▆▅▄▃▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃▁▁▁▁▁▁▄▅▆▅▆▆▆▅▅▄▅▅▆▅▆▇▆▆▇▆▇▇ █
#   277 μs        Histogram: log(frequency) by time       1.73 ms <
#
#  Memory estimate: 1.04 MiB, allocs estimate: 507.

# %%
@benchmark ConstrainedGaussians.generate_batch_CPU($RNG,$N,$d)
# Out:
# BenchmarkTools.Trial: 10000 samples with 1 evaluation per sample.
#  Range (min … max):   88.000 μs …  15.030 ms  ┊ GC (min … max):  0.00% … 99.17%
#  Time  (median):     103.291 μs               ┊ GC (median):     0.00%
#  Time  (mean ± σ):   118.591 μs ± 243.549 μs  ┊ GC (mean ± σ):  11.52% ±  7.72%
#
#              █▇▄▆▅▁
#   ▄▃▂▃▂▂▂▂▂▂▇██████▇▆▅▅▄▄▃▃▃▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂ ▃
#   88 μs            Histogram: frequency by time          152 μs <
#
#  Memory estimate: 340.20 KiB, allocs estimate: 18.
